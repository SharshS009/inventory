# %%
import pandas as pd 
import numpy as np 
df = pd.read_csv("C:\\Users\\DELL\\Downloads\\archive\\final_job_list.csv")
df
# Out:
#                                                  Title  \
# 0                 Staff Applied Scientist, Marketplace
# 1    Prompt Engineer for Generative AI (chatbot and...
# 2                       Data Systems Analyst/Architect
# 3                       AIOps Principle Data Scientist
# 4                                   Sr. Data Scientist
# ..                                                 ...
# 687                      Senior Staff AI Data Engineer
# 688                      Senior Staff AI Data Engineer
# 689                      Senior Staff AI Data Engineer
# 690                      Senior Staff AI Data Engineer
# 691                      Senior Staff AI Data Engineer
#
#                                      Company Location Type of Positions  \
# 0                               ThredUp Inc.       CA         Full-time
# 1                    Vicarious Talent Agency       WA         Full-time
# 2    General Dynamics Information Technology   Remote         Full-time
# 3                                 CVS Health       CT         Full-time
# 4                                Altak Group   Remote         Full-time
# ..                                       ...      ...               ...
# 687                  Recruiting From Scratch       TX         Full-time
# 688                  Recruiting From Scratch       CO         Full-time
# 689                  Recruiting From Scratch       HI         Full-time
# 690                  Recruiting From Scratch       CA         Full-time
# 691                  Recruiting From Scratch       CA         Full-time
#
#                                        Job Description    Salary  \
# 0    \nAbout thredUP thredUP is transforming resale...  190000.0
# 1    We are Vicarious, a talent agency that represe...   70000.0
# 2    Clearance Level None Category Data Science Loc...  104000.0
# 3    \nBring your heart to CVS Health. Every one of...  140000.0
# 4    Job Summary:\nWe are seeking an experienced Da...  136000.0
# ..                                                 ...       ...
# 687  \n\n\nWho is \nRecruiting from Scratch \n: \n\...  160000.0
# 688  \n\n\nWho is \nRecruiting from Scratch \n: \n\...  160000.0
# 689  \n\n\nWho is \nRecruiting from Scratch \n: \n\...  160000.0
# 690  \n\n\nWho is \nRecruiting from Scratch \n: \n\...  160000.0
# 691  \n\n\nWho is \nRecruiting from Scratch \n: \n\...  160000.0
#
#                                      Identified_Skills
# 0         ['python', 'machine learning', 'aws', 'sql']
# 1    ['python', 'machine learning', 'deep learning'...
# 2    ['machine learning', 'aws', 'azure', 'nosql', ...
# 3         ['python', 'machine learning', 'aws', 'gcp']
# 4    ['python', 'machine learning', 'tableau', 'aws...
# ..                                                 ...
# 687  ['python', 'pandas', 'machine learning', 'aws'...
# 688  ['python', 'pandas', 'machine learning', 'aws'...
# 689  ['python', 'pandas', 'machine learning', 'aws'...
# 690  ['python', 'pandas', 'machine learning', 'aws'...
# 691  ['python', 'pandas', 'machine learning', 'aws'...
#
# [692 rows x 7 columns]

# %%
#convert csv file into excel file 
df.to_csv('acsvtoexcel.csv')
    #if  you don't want that index colunm in excel file that you can run following code:
    #df.to_csv('csvtoexcel.csv',index False)

# %%
#To analysis numericle data of existing data
df.describe()
# Out:
#               Salary
# count     692.000000
# mean   131428.635838
# std     39712.952798
# min      4145.000000
# 25%    101000.000000
# 50%    149532.000000
# 75%    160000.000000
# max    268000.000000
