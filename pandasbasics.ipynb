# %%
import pandas as pd 
import numpy as np 
#from pandas_profiling import ProfileReport
dict= {
"name": [ 'harry', 'rohan', 'skillf', 'shubh'],
"marks": [92, 34, 24, 17],
"city": ['rampur', 'kolkata', 'bareilly', 'antarctica']
}

# %%
#Convert dictionary into tabuler format 
df = pd.DataFrame(dict)
df
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
#convert csv file into excel file 
df.to_csv('df.csv')
    #if  you don't want that index colunm in excel file that you can run following code:
    #df.to_csv('df.csv',index False)

# %%
#show values from above 
df.head()
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
#show values from below 
df.tail()
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24    bareilly
# 3   shubh     17  antarctica

# %%
##To analysis numericle data of existing table
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
#print any perticuler column 
df["name"]
# Out:
# 0     harry
# 1     rohan
# 2    skillf
# 3     shubh
# Name: name, dtype: object

# %%
#Give different type of indexing 
df.index= ['first','Second','Third','Four']
df
# Out:
#           name  marks        city
# first    harry     92      rampur
# Second   rohan     34     kolkata
# Third   skillf     24    bareilly
# Four     shubh     17  antarctica

# %%
#create random dataframe 
newdf = pd.DataFrame(np.random.rand(334,5), index= np.arange(334))
newdf
# Out:
#             0         1         2         3         4
# 0    0.074622  0.455307  0.677998  0.902272  0.553229
# 1    0.449733  0.361691  0.081482  0.748435  0.136001
# 2    0.869935  0.214975  0.794424  0.431712  0.928985
# 3    0.508788  0.738437  0.565830  0.694045  0.338701
# 4    0.171541  0.579645  0.735729  0.347354  0.824498
# ..        ...       ...       ...       ...       ...
# 329  0.908583  0.296828  0.682632  0.805674  0.028366
# 330  0.906280  0.017307  0.240716  0.494617  0.706404
# 331  0.814631  0.667321  0.122152  0.354800  0.162302
# 332  0.001000  0.159427  0.952770  0.378986  0.395784
# 333  0.045280  0.899353  0.373673  0.371922  0.463763
#
# [334 rows x 5 columns]

# %%
#To check data type of colunm 
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
#to transport colunm into raw or raw into column 
newdf.T
# Out:
#           0         1         2         3         4         5         6    \
# A  123.000000  0.879296  0.590971  0.314258  0.856098  0.253192  0.022250
# B    0.841301  0.426164  0.162024  0.775099  0.341036  0.875578  0.649552
# C    0.284148  0.433320  0.057445  0.601450  0.487218  0.011056  0.548675
# D    0.134748  0.127514  0.011299  0.655396  0.364168  0.924452  0.347169
# E    0.657888  0.340986  0.860194  0.501003  0.642204  0.862033  0.004363
#
#         7         8         9    ...       324       325       326       327  \
# A  0.667452  0.197285  0.054204  ...  0.247684  0.317231  0.041145  0.615993
# B  0.793863  0.705345  0.815281  ...  0.507305  0.820993  0.350739  0.405382
# C  0.491464  0.571511  0.793029  ...  0.309909  0.425134  0.647571  0.227680
# D  0.001572  0.526014  0.298443  ...  0.878334  0.420382  0.345534  0.133365
# E  0.669847  0.452091  0.765633  ...  0.034629  0.100133  0.714183  0.162469
#
# ...

# %%
#Make a view of dataframe 
newdf2 = newdf
    #In this case if we make changes in newdf2 then it's also make change in newdf.

# %%
#Create a coppy of dataframe 
newdf3 = newdf.copy()
 #In this case If we change newdf3, then newdf will not change, it will remain as it is.

# %%
#Update values using loc
newdf.loc[0,'A'] = 12

# %%
#If you enter any wrong index then it will create new colunm and assign value which you give 
newdf.loc[0,0] = 111
newdf.head()
# Out:
#             A         B         C         D         E      0
# 0  122.000000  0.841301  0.284148  0.134748  0.657888  111.0
# 1    0.879296  0.426164  0.433320  0.127514  0.340986    NaN
# 2    0.590971  0.162024  0.057445  0.011299  0.860194    NaN
# 3    0.314258  0.775099  0.601450  0.655396  0.501003    NaN
# 4    0.856098  0.341036  0.487218  0.364168  0.642204    NaN

# %%
#Delete any perticuler colunm 
newdf = newdf.drop(0 , axis=1)
    #you have to give axis Compulsory otherwise its remove values from raw

# %%
#To print any specific column and raw 
newdf.loc[[1,2],['C','D']]
    #if you want to print all colunm and selected raw OR all raw and selected colunm then you can use ":" to print all.
    #newdf.loc[[1,2],:]    <--- like this

# %%
#Insert queries in dataframe (conditional)
a= newdf.loc[(newdf['A']<0.3) & (newdf['B']<0.5)]
    #In this case we check that values of column A is lessthen 0.3 and also check that values of colunm B is lessthen 0.5.
a.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 #Insert queries in dataframe (conditional)
# ----> 2 a= newdf.loc[(newdf['A']<0.3) & (newdf['B']<0.5)]
#       3     #In this case we check that values of column A is lessthen 0.3 and also check that values of colunm B is lessthen 0.5.
#       4 a.head()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
# ...

# %%
#If Dataframe column/raw name different but you want to access them using index (0,1,2,..)
newdf.iloc[0][1]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_67660\1865719206.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   newdf.iloc[0][1]
# 0.8413013468166969

# %%
#if you want to reset indext of any dataframe 
newdf.reset_index()
newdf.head()
# Out:
#             A         B         C         D         E
# 0  122.000000  0.841301  0.284148  0.134748  0.657888
# 1    0.879296  0.426164  0.433320  0.127514  0.340986
# 2    0.590971  0.162024  0.057445  0.011299  0.860194
# 3    0.314258  0.775099  0.601450  0.655396  0.501003
# 4    0.856098  0.341036  0.487218  0.364168  0.642204

# %%
#it's used to identify where is value is 0(zero)/None , if value is 0/None  then its return TRUE 
newdf['A'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 330    False
# 331    False
# 332    False
# 333    False
# A       True
# Name: A, Length: 335, dtype: bool

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy":  [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT]
                   })
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
#Drop the rows where at least one element is missing
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
#to know the inforamtion about dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes

# %%
#Count colunm values  
df['toy'].value_counts(dropna=False)
# Out:
# toy
# NaN          1
# Batmobile    1
# Bullwhip     1
# Name: count, dtype: int64

# %%
data = pd.read_excel('Store.xls')
    #If  you want to read perticuler sheet of your excel file you can write as following :
        #data = pd.read_excel('Store.xls', sheet_name= "sheet1")
data.head(3)

# %%
#i want to print the data which region is "South" or "West". 
option = ['South','West']
a  = data[data["Region"].isin(option)]
a
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 3988  US-2016-159415 2016-04-17 2016-04-22  Standard Class    CS-12175
# 3991  CA-2015-161998 2015-05-01 2015-05-05  Standard Class    DB-13120
# 3992  CA-2015-161998 2015-05-01 2015-05-05  Standard Class    DB-13120
# 3993  CA-2015-161998 2015-05-01 2015-05-05  Standard Class    DB-13120
# 3999  US-2015-149629 2015-07-17 2015-07-20    Second Class    MP-17965
#
#         Customer Name    Segment        Country              City       State  \
# ...
